# %%
import os
import pandas as pd
import string
import nltk
import nltk.corpus
from nltk.tokenize import word_tokenize
from nltk import Tree

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# Defining a function for reading the text documents
def Document(*doc_path):
  for files in doc_path:
    data_files = open(files)
    data_read = data_files.read()
  return data_read

# %%
docs = Document(r'/content/Secret Garden.txt')
docs
# Out:
# 'Aristide Valentin, Chief of the Paris Police, was late for his dinner, and some of his guests began to arrive before him. These were, however, reassured by his confidential servant, Ivan, the old man with a scar, and a face almost as grey as his moustaches, who always sat at a table in the entrance hall—a hall hung with weapons. Valentin’s house was perhaps as peculiar and celebrated as its master. It was an old house, with high walls and tall poplars almost overhanging the Seine; but the oddity—and perhaps the police value—of its architecture was this: that there was no ultimate exit at all except through this front door, which was guarded by Ivan and the armoury. The garden was large and elaborate, and there were many exits from the house into the garden. But there was no exit from the garden into the world outside; all round it ran a tall, smooth, unscalable wall with special spikes at the top; no bad garden, perhaps, for a man to reflect in whom some hundred criminals had sworn to kill.\nAs Ivan explained to the guests, their host had telephoned that he was detained for ten minutes. He was, in truth, making some last arrangements about executions and such ugly things; and though these duties were rootedly repulsive to him, he always performed them with precision. Ruthless in the pursuit of criminals, he was very mild about their punishment. Since he had been supreme over French—and largely over European—policial methods, his great influence had been honourably used for the mitigation of sentences and the purification of prisons. He was one of the great humanitarian French freethinkers; and the only thing wrong with them is that they make mercy even colder than justice.\nWhen Valentin arrived he was already dressed in black clothes and the red rosette—an elegant figure, his dark beard already streaked with grey. He went straight through his house to his study, which opened on the grounds behind. The garden door of it was open, and after he had carefully locked his box in its official place, he stood for a few seconds at the open door looking out upon the garden. A sharp moon was fighting with the flying rags and tatters of a storm, and Valentin regarded it with a wistfulness unusual in such scientific natures as his. Perhaps such scientific natures have some psychic prevision of the most tremendous problem of their lives. From any such occult mood, at least, he quickly recovered, for he knew he was late, and that his guests had already begun to arrive. A glance at his drawing-room when he entered it was enough to make certain that his principal guest was not there, at any rate. He saw all the other pillars of the little party; he saw Lord Galloway, the English Ambassador—a choleric old man with a russet face like an apple, wearing the blue ribbon of the Garter. He saw Lady Galloway, slim and threadlike, with silver hair and a face sensitive and superior. He saw her daughter, Lady Margaret Graham, a\n \npale and pretty girl with an elfish face and copper-coloured hair. He saw the Duchess of Mont St. Michel, black-eyed and opulent, and with her her two daughters, black-eyed and opulent also. He saw Dr. Simon, a typical French scientist, with glasses, a pointed brown beard, and a forehead barred with those parallel wrinkles which are the penalty of superciliousness, since they come through constantly elevating the eyebrows. He saw Father Brown, of Cobhole, in Essex, whom he had recently met in England. He saw—perhaps with more interest than any of these—a tall man in uniform, who had bowed to the Galloways without receiving any very hearty acknowledgment, and who now advanced alone to pay his respects to his host. This was Commandant O’Brien, of the French Foreign Legion. He was a slim yet somewhat swaggering figure, clean-shaven, dark- haired, and blue-eyed, and, as seemed natural in an officer of that famous regiment of victorious failures and successful suicides, he had an air at once dashing and melancholy. He was by birt ...

# %%
grammar = """
     NP: {<JJ>*<NN*>+}
     {<JJ>*<NN*><CC>*<NN*>+}
     {<DT>*<JJ>*<NN>+}
     {<JJ>*<NNS>+}
    """

# %%
chunked_NP = nltk.RegexpParser(grammar)

def chunked_text(data):
  sentences = nltk.sent_tokenize(data)
  sentences = [nltk.word_tokenize(sent) for sent in sentences]
  sentences = [nltk.pos_tag(sent) for sent in sentences]
  sentences = [chunked_NP.parse(sent) for sent in sentences]
  return sentences

# %%
tag_of_words = chunked_text(docs)
tag_of_words
# Out:
# [Tree('S', [('Aristide', 'NNP'), ('Valentin', 'NNP'), (',', ','), ('Chief', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Paris', 'NNP'), ('Police', 'NNP'), (',', ','), ('was', 'VBD'), ('late', 'JJ'), ('for', 'IN'), ('his', 'PRP$'), Tree('NP', [('dinner', 'NN')]), (',', ','), ('and', 'CC'), ('some', 'DT'), ('of', 'IN'), ('his', 'PRP$'), Tree('NP', [('guests', 'NNS')]), ('began', 'VBD'), ('to', 'TO'), ('arrive', 'VB'), ('before', 'IN'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('These', 'DT'), ('were', 'VBD'), (',', ','), ('however', 'RB'), (',', ','), ('reassured', 'VBN'), ('by', 'IN'), ('his', 'PRP$'), Tree('NP', [('confidential', 'JJ'), ('servant', 'NN')]), (',', ','), ('Ivan', 'NNP'), (',', ','), ('the', 'DT'), Tree('NP', [('old', 'JJ'), ('man', 'NN')]), ('with', 'IN'), ('a', 'DT'), Tree('NP', [('scar', 'NN')]), (',', ','), ('and', 'CC'), ('a', 'DT'), Tree('NP', [('face', 'NN')]), ('almost', 'RB'), ('as', 'RB'), ('grey', 'JJ'), ('as', 'IN'), ('his', 'PRP$'), Tree('NP', [('moustaches', 'NNS')]), (',', ','), ('who', 'WP'), ('always', 'RB'), ('sat', 'VBD'), ('at', 'IN'), ('a', 'DT'), Tree('NP', [('table', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('entrance', 'NN'), ('hall—a', 'NN'), ('hall', 'NN'), ('hung', 'NN')]), ('with', 'IN'), Tree('NP', [('weapons', 'NNS')]), ('.', '.')]),
#  Tree('S', [('Valentin', 'NNP'), ('’', 'NNP'), Tree('NP', [('s', 'NN'), ('house', 'NN')]), ('was', 'VBD'), ('perhaps', 'RB'), ('as', 'IN'), Tree('NP', [('peculiar', 'NN')]), ('and', 'CC'), ('celebrated', 'VBD'), ('as', 'IN'), ('its', 'PRP$'), Tree('NP', [('master', 'NN')]), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('an', 'DT'), Tree('NP', [('old', 'JJ'), ('house', 'NN')]), (',', ','), ('with', 'IN'), Tree('NP', [('high', 'JJ'), ('walls', 'NNS')]), ('and', 'CC'), Tree('NP', [('tall', 'JJ'), ('poplars', 'NNS')]), ('almost', 'RB'), ('overhanging', 'VBG'), ('the', 'DT'), ('Seine', 'NNP'), (';', ':'), ('but', 'CC'), ('the', 'DT'), Tree('NP', [('oddity—and', 'NN')]), ('perhaps', 'RB'), ('the', 'DT'), Tree('NP', [('police', 'NN')]), ('value—of', 'VBD'), ('its', 'PRP$'), Tree('NP', [('architecture', 'NN')]), ('was', 'VBD'), ('this', 'DT'), (':', ':'), ('that', 'IN'), ('there', 'EX'), ('was', 'VBD'), ('no', 'DT'), Tree('NP', [('ultimate', 'JJ'), ('exit', 'NN')]), ('at', 'IN'), ('all', 'DT'), ('except', 'IN'), ('through', 'IN'), ('this', 'DT'), Tree('NP', [('front', 'JJ'), ('door', 'NN')]), (',', ','), ('which', 'WDT'), ('was', 'VBD'), ('guarded', 'VBN'), ('by', 'IN'), ('Ivan', 'NNP'), ('and', 'CC'), ('the', 'DT'), Tree('NP', [('armoury', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('garden', 'NN')]), ('was', 'VBD'), ('large', 'JJ'), ('and', 'CC'), ('elaborate', 'JJ'), (',', ','), ('and', 'CC'), ('there', 'EX'), ('were', 'VBD'), Tree('NP', [('many', 'JJ'), ('exits', 'NNS')]), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('house', 'NN')]), ('into', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('there', 'EX'), ('was', 'VBD'), ('no', 'DT'), Tree('NP', [('exit', 'NN')]), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('into', 'IN'), ('the', 'DT'), Tree('NP', [('world', 'NN')]), ('outside', 'IN'), (';', ':'), ('all', 'DT'), ('round', 'VBP'), ('it', 'PRP'), ('ran', 'VBD'), ('a', 'DT'), Tree('NP', [('tall', 'NN')]), (',', ','), ('smooth', 'CC'), (',', ','), Tree('NP', [('unscalable', 'JJ'), ('wall', 'NN')]), ('with', 'IN'), Tree('NP', [('special', 'JJ'), ('spikes', 'NNS')]), ('at', 'IN'), ('the', 'DT'), Tree('NP', [('top', 'NN')]), (';', ':'), ('no', 'DT'), Tree('NP', [('bad', 'JJ'), ('garden', 'NN')]), (',', ','), ('perhaps', 'RB'), (',', ','), ('for', 'IN'), ('a', 'DT'), Tree('NP', [('man', 'NN')]), ('to', 'TO'), ('reflect', 'VB'), ('in', 'IN'), ('whom', 'WP'), ('some', 'DT'), ('hundred', 'CD'), Tree('NP', [('criminals', 'NNS')]), ('had', 'VBD'), ('sworn', 'VBN'), ('to', 'TO'), ('kill', 'VB'), ('.', '.')]),
#  Tree('S', [('As', 'IN'), ('Ivan', 'NNP'), ('explained', 'VBD'), ('to', 'TO'), ('the', 'DT'), Tree('NP', [('guests', 'NNS')]), (',', ','), ('their', 'PRP$'), Tree('NP', [('host', 'NN')]), ('had', 'VBD'), ('telephoned', 'VBN'), ('that', 'IN'), ('he', 'PRP'), ('was', 'VBD'), ('detained', 'VBN'), ('for', 'IN'), Tree('NP', [('ten', 'JJ'), ('minutes', 'NNS')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), (',', ','), ('in', 'IN'), Tree('NP', [('truth', 'NN')]), (',', ','), ('making', 'VBG'), ('some', 'DT'), Tree('NP', [('last', 'JJ'), ('arrangements', 'NNS')]), ('about', 'IN'), Tree('NP', [('executions', 'NNS')]), ('and', 'CC'), Tree('NP', [('such', 'JJ'), ('ugly', 'JJ'), ('things', 'NNS')]), (';', ':'), ('and', 'CC'), ('though', 'IN'), ('these', 'DT'), Tree('NP', [('duties', 'NNS')]), ('were', 'VBD'), ('rootedly', 'RB'), ('repulsive', 'JJ'), ('to', 'TO'), ('him', 'PRP'), (',', ','), ('he', 'PRP'), ('always', 'RB'), ('performed', 'VBD'), ('them', 'PRP'), ('with', 'IN'), Tree('NP', [('precision', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('Ruthless', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('pursuit', 'NN')]), ('of', 'IN'), Tree('NP', [('criminals', 'NNS')]), (',', ','), ('he', 'PRP'), ('was', 'VBD'), ('very', 'RB'), ('mild', 'JJ'), ('about', 'IN'), ('their', 'PRP$'), Tree('NP', [('punishment', 'NN')]), ('.', '.')]),
#  Tree('S', [('Since', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('been', 'VBN'), ('supreme', 'VBN'), ('over', 'IN'), ('French—and', 'NNP'), ('largely', 'RB'), ('over', 'IN'), ('European—policial', 'NNP'), Tree('NP', [('methods', 'NNS')]), (',', ','), ('his', 'PRP$'), Tree('NP', [('great', 'JJ'), ('influence', 'NN')]), ('had', 'VBD'), ('been', 'VBN'), ('honourably', 'RB'), ('used', 'VBN'), ('for', 'IN'), ('the', 'DT'), Tree('NP', [('mitigation', 'NN')]), ('of', 'IN'), Tree('NP', [('sentences', 'NNS')]), ('and', 'CC'), ('the', 'DT'), Tree('NP', [('purification', 'NN')]), ('of', 'IN'), Tree('NP', [('prisons', 'NNS')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('great', 'JJ'), ('humanitarian', 'JJ'), ('French', 'JJ'), ('freethinkers', 'NNS')]), (';', ':'), ('and', 'CC'), ('the', 'DT'), Tree('NP', [('only', 'JJ'), ('thing', 'NN')]), ('wrong', 'JJ'), ('with', 'IN'), ('them', 'PRP'), ('is', 'VBZ'), ('that', 'IN'), ('they', 'PRP'), ('make', 'VBP'), ('mercy', 'JJ'), ('even', 'RB'), ('colder', 'JJR'), ('than', 'IN'), Tree('NP', [('justice', 'NN')]), ('.', '.')]),
#  Tree('S', [('When', 'WRB'), ('Valentin', 'NNP'), ('arrived', 'VBD'), ('he', 'PRP'), ('was', 'VBD'), ('already', 'RB'), ('dressed', 'VBN'), ('in', 'IN'), Tree('NP', [('black', 'JJ'), ('clothes', 'NNS')]), ('and', 'CC'), ('the', 'DT'), Tree('NP', [('red', 'JJ'), ('rosette—an', 'NN')]), Tree('NP', [('elegant', 'JJ'), ('figure', 'NN')]), (',', ','), ('his', 'PRP$'), Tree('NP', [('dark', 'JJ'), ('beard', 'NN')]), ('already', 'RB'), ('streaked', 'VBN'), ('with', 'IN'), Tree('NP', [('grey', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('went', 'VBD'), ('straight', 'RB'), ('through', 'IN'), ('his', 'PRP$'), Tree('NP', [('house', 'NN')]), ('to', 'TO'), ('his', 'PRP$'), Tree('NP', [('study', 'NN')]), (',', ','), ('which', 'WDT'), ('opened', 'VBD'), ('on', 'IN'), ('the', 'DT'), Tree('NP', [('grounds', 'NNS')]), ('behind', 'IN'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('garden', 'NN'), ('door', 'NN')]), ('of', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('open', 'JJ'), (',', ','), ('and', 'CC'), ('after', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('carefully', 'RB'), ('locked', 'VBN'), ('his', 'PRP$'), Tree('NP', [('box', 'NN')]), ('in', 'IN'), ('its', 'PRP$'), Tree('NP', [('official', 'JJ'), ('place', 'NN')]), (',', ','), ('he', 'PRP'), ('stood', 'VBD'), ('for', 'IN'), ('a', 'DT'), Tree('NP', [('few', 'JJ'), ('seconds', 'NNS')]), ('at', 'IN'), ('the', 'DT'), Tree('NP', [('open', 'JJ'), ('door', 'NN')]), ('looking', 'VBG'), ('out', 'RP'), ('upon', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('.', '.')]),
#  Tree('S', [('A', 'DT'), Tree('NP', [('sharp', 'JJ'), ('moon', 'NN')]), ('was', 'VBD'), ('fighting', 'VBG'), ('with', 'IN'), ('the', 'DT'), ('flying', 'VBG'), Tree('NP', [('rags', 'NNS')]), ('and', 'CC'), Tree('NP', [('tatters', 'NNS')]), ('of', 'IN'), ('a', 'DT'), Tree('NP', [('storm', 'NN')]), (',', ','), ('and', 'CC'), ('Valentin', 'NNP'), ('regarded', 'VBD'), ('it', 'PRP'), ('with', 'IN'), ('a', 'DT'), ('wistfulness', 'JJ'), ('unusual', 'JJ'), ('in', 'IN'), Tree('NP', [('such', 'JJ'), ('scientific', 'JJ'), ('natures', 'NNS')]), ('as', 'IN'), ('his', 'PRP$'), ('.', '.')]),
#  Tree('S', [('Perhaps', 'RB'), Tree('NP', [('such', 'JJ'), ('scientific', 'JJ'), ('natures', 'NNS')]), ('have', 'VBP'), ('some', 'DT'), Tree('NP', [('psychic', 'JJ'), ('prevision', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), Tree('NP', [('tremendous', 'JJ'), ('problem', 'NN')]), ('of', 'IN'), ('their', 'PRP$'), Tree('NP', [('lives', 'NNS')]), ('.', '.')]),
#  Tree('S', [('From', 'IN'), ('any', 'DT'), Tree('NP', [('such', 'JJ'), ('occult', 'NN'), ('mood', 'NN')]), (',', ','), ('at', 'IN'), ('least', 'JJS'), (',', ','), ('he', 'PRP'), ('quickly', 'RB'), ('recovered', 'VBD'), (',', ','), ('for', 'IN'), ('he', 'PRP'), ('knew', 'VBD'), ('he', 'PRP'), ('was', 'VBD'), ('late', 'JJ'), (',', ','), ('and', 'CC'), ('that', 'IN'), ('his', 'PRP$'), Tree('NP', [('guests', 'NNS')]), ('had', 'VBD'), ('already', 'RB'), ('begun', 'VBN'), ('to', 'TO'), ('arrive', 'VB'), ('.', '.')]),
#  Tree('S', [('A', 'DT'), Tree('NP', [('glance', 'NN')]), ('at', 'IN'), ('his', 'PRP$'), Tree('NP', [('drawing-room', 'NN')]), ('when', 'WRB'), ('he', 'PRP'), ('entered', 'VBD'), ('it', 'PRP'), ('was', 'VBD'), ('enough', 'JJ'), ('to', 'TO'), ('make', 'VB'), ('certain', 'JJ'), ('that', 'IN'), ('his', 'PRP$'), Tree('NP', [('principal', 'JJ'), ('guest', 'NN')]), ('was', 'VBD'), ('not', 'RB'), ('there', 'RB'), (',', ','), ('at', 'IN'), ('any', 'DT'), Tree('NP', [('rate', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('all', 'PDT'), ('the', 'DT'), Tree('NP', [('other', 'JJ'), ('pillars', 'NNS')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('little', 'JJ'), ('party', 'NN')]), (';', ':'), ('he', 'PRP'), ('saw', 'VBD'), ('Lord', 'NNP'), ('Galloway', 'NNP'), (',', ','), ('the', 'DT'), ('English', 'NNP'), ('Ambassador—a', 'NNP'), Tree('NP', [('choleric', 'JJ'), ('old', 'JJ'), ('man', 'NN')]), ('with', 'IN'), ('a', 'DT'), Tree('NP', [('russet', 'JJ'), ('face', 'NN')]), ('like', 'IN'), ('an', 'DT'), Tree('NP', [('apple', 'NN')]), (',', ','), ('wearing', 'VBG'), ('the', 'DT'), Tree('NP', [('blue', 'JJ'), ('ribbon', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('Garter', 'NNP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('Lady', 'NNP'), ('Galloway', 'NNP'), (',', ','), Tree('NP', [('slim', 'NN')]), ('and', 'CC'), Tree('NP', [('threadlike', 'NN')]), (',', ','), ('with', 'IN'), Tree('NP', [('silver', 'JJ'), ('hair', 'NN')]), ('and', 'CC'), ('a', 'DT'), Tree('NP', [('face', 'NN')]), ('sensitive', 'JJ'), ('and', 'CC'), ('superior', 'JJ'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('her', 'PRP'), Tree('NP', [('daughter', 'NN')]), (',', ','), ('Lady', 'NNP'), ('Margaret', 'NNP'), ('Graham', 'NNP'), (',', ','), ('a', 'DT'), Tree('NP', [('pale', 'NN')]), ('and', 'CC'), ('pretty', 'RB'), Tree('NP', [('girl', 'NN')]), ('with', 'IN'), ('an', 'DT'), Tree('NP', [('elfish', 'JJ'), ('face', 'NN')]), ('and', 'CC'), Tree('NP', [('copper-coloured', 'JJ'), ('hair', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('the', 'DT'), ('Duchess', 'NNP'), ('of', 'IN'), ('Mont', 'NNP'), ('St.', 'NNP'), ('Michel', 'NNP'), (',', ','), ('black-eyed', 'JJ'), ('and', 'CC'), ('opulent', 'JJ'), (',', ','), ('and', 'CC'), ('with', 'IN'), ('her', 'PRP$'), ('her', 'PRP$'), ('two', 'CD'), Tree('NP', [('daughters', 'NNS')]), (',', ','), ('black-eyed', 'JJ'), ('and', 'CC'), Tree('NP', [('opulent', 'NN')]), ('also', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('Dr.', 'NNP'), ('Simon', 'NNP'), (',', ','), ('a', 'DT'), Tree('NP', [('typical', 'JJ'), ('French', 'JJ'), ('scientist', 'NN')]), (',', ','), ('with', 'IN'), Tree('NP', [('glasses', 'NNS')]), (',', ','), ('a', 'DT'), Tree('NP', [('pointed', 'JJ'), ('brown', 'JJ'), ('beard', 'NN')]), (',', ','), ('and', 'CC'), ('a', 'DT'), Tree('NP', [('forehead', 'NN')]), ('barred', 'VBN'), ('with', 'IN'), ('those', 'DT'), Tree('NP', [('parallel', 'NNS'), ('wrinkles', 'NNS')]), ('which', 'WDT'), ('are', 'VBP'), ('the', 'DT'), Tree('NP', [('penalty', 'NN')]), ('of', 'IN'), Tree('NP', [('superciliousness', 'NN')]), (',', ','), ('since', 'IN'), ('they', 'PRP'), ('come', 'VBP'), ('through', 'IN'), ('constantly', 'RB'), ('elevating', 'VBG'), ('the', 'DT'), Tree('NP', [('eyebrows', 'NNS')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('Father', 'NNP'), ('Brown', 'NNP'), (',', ','), ('of', 'IN'), ('Cobhole', 'NNP'), (',', ','), ('in', 'IN'), ('Essex', 'NNP'), (',', ','), ('whom', 'WP'), ('he', 'PRP'), ('had', 'VBD'), ('recently', 'RB'), ('met', 'VBN'), ('in', 'IN'), ('England', 'NNP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw—perhaps', 'VBZ'), ('with', 'IN'), ('more', 'JJR'), Tree('NP', [('interest', 'NN')]), ('than', 'IN'), ('any', 'DT'), ('of', 'IN'), Tree('NP', [('these—a', 'NN')]), Tree('NP', [('tall', 'JJ'), ('man', 'NN')]), ('in', 'IN'), ('uniform', 'JJ'), (',', ','), ('who', 'WP'), ('had', 'VBD'), ('bowed', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('Galloways', 'NNP'), ('without', 'IN'), ('receiving', 'VBG'), ('any', 'DT'), ('very', 'RB'), Tree('NP', [('hearty', 'JJ'), ('acknowledgment', 'NN')]), (',', ','), ('and', 'CC'), ('who', 'WP'), ('now', 'RB'), ('advanced', 'VBP'), ('alone', 'RB'), ('to', 'TO'), ('pay', 'VB'), ('his', 'PRP$'), Tree('NP', [('respects', 'NNS')]), ('to', 'TO'), ('his', 'PRP$'), Tree('NP', [('host', 'NN')]), ('.', '.')]),
#  Tree('S', [('This', 'DT'), ('was', 'VBD'), ('Commandant', 'NNP'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), (',', ','), ('of', 'IN'), ('the', 'DT'), ('French', 'JJ'), ('Foreign', 'NNP'), ('Legion', 'NNP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('slim', 'JJ'), ('yet', 'RB'), ('somewhat', 'RB'), Tree('NP', [('swaggering', 'JJ'), ('figure', 'NN')]), (',', ','), ('clean-shaven', 'JJ'), (',', ','), ('dark-', 'JJ'), ('haired', 'VBN'), (',', ','), ('and', 'CC'), ('blue-eyed', 'JJ'), (',', ','), ('and', 'CC'), (',', ','), ('as', 'IN'), ('seemed', 'JJ'), ('natural', 'JJ'), ('in', 'IN'), ('an', 'DT'), Tree('NP', [('officer', 'NN')]), ('of', 'IN'), ('that', 'DT'), Tree('NP', [('famous', 'JJ'), ('regiment', 'NN')]), ('of', 'IN'), Tree('NP', [('victorious', 'JJ'), ('failures', 'NNS')]), ('and', 'CC'), Tree('NP', [('successful', 'JJ'), ('suicides', 'NNS')]), (',', ','), ('he', 'PRP'), ('had', 'VBD'), ('an', 'DT'), Tree('NP', [('air', 'NN')]), ('at', 'IN'), ('once', 'RB'), ('dashing', 'VBG'), ('and', 'CC'), Tree('NP', [('melancholy', 'NNS')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('by', 'IN'), Tree('NP', [('birth', 'NN')]), ('an', 'DT'), Tree('NP', [('Irish', 'JJ'), ('gentleman', 'NN')]), (',', ','), ('and', 'CC'), ('in', 'IN'), Tree('NP', [('boyhood', 'NN')]), ('had', 'VBD'), ('known', 'VBN'), ('the', 'DT'), ('Galloways—especially', 'NNP'), ('Margaret', 'NNP'), ('Graham', 'NNP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('had', 'VBD'), ('left', 'VBN'), ('his', 'PRP$'), Tree('NP', [('country', 'NN')]), ('after', 'IN'), ('some', 'DT'), Tree('NP', [('crash', 'NN')]), ('of', 'IN'), Tree('NP', [('debts', 'NNS')]), (',', ','), ('and', 'CC'), ('now', 'RB'), ('expressed', 'VBN'), ('his', 'PRP$'), Tree('NP', [('complete', 'JJ'), ('freedom', 'NN')]), ('from', 'IN'), Tree('NP', [('British', 'JJ'), ('etiquette', 'NN')]), ('by', 'IN'), ('swinging', 'VBG'), ('about', 'RB'), ('in', 'IN'), Tree('NP', [('uniform', 'NN')]), (',', ','), Tree('NP', [('sabre', 'NN')]), ('and', 'CC'), Tree('NP', [('spurs', 'NN')]), ('.', '.')]),
#  Tree('S', [('When', 'WRB'), ('he', 'PRP'), ('bowed', 'VBD'), ('to', 'TO'), ('the', 'DT'), ('Ambassador', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), Tree('NP', [('family', 'NN')]), (',', ','), ('Lord', 'NNP'), ('and', 'CC'), ('Lady', 'NNP'), ('Galloway', 'NNP'), Tree('NP', [('bent', 'NN'), ('stiffly', 'NN')]), (',', ','), ('and', 'CC'), ('Lady', 'NNP'), ('Margaret', 'NNP'), ('looked', 'VBD'), ('away', 'RB'), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('for', 'IN'), ('whatever', 'WDT'), Tree('NP', [('old', 'JJ'), ('causes', 'NNS')]), Tree('NP', [('such', 'JJ'), ('people', 'NNS')]), ('might', 'MD'), ('be', 'VB'), ('interested', 'JJ'), ('in', 'IN'), ('each', 'DT'), ('other', 'JJ'), (',', ','), ('their', 'PRP$'), ('distinguished', 'VBN'), Tree('NP', [('host', 'NN')]), ('was', 'VBD'), ('not', 'RB'), ('specially', 'RB'), ('interested', 'JJ'), ('in', 'IN'), ('them', 'PRP'), ('.', '.')]),
#  Tree('S', [('No', 'DT'), Tree('NP', [('one', 'NN')]), ('of', 'IN'), ('them', 'PRP'), ('at', 'IN'), ('least', 'JJS'), ('was', 'VBD'), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('eyes', 'NNS')]), ('the', 'DT'), Tree('NP', [('guest', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('evening', 'NN')]), ('.', '.')]),
#  Tree('S', [('Valentin', 'NNP'), ('was', 'VBD'), ('expecting', 'VBG'), (',', ','), ('for', 'IN'), Tree('NP', [('special', 'JJ'), ('reasons', 'NNS')]), (',', ','), ('a', 'DT'), Tree('NP', [('man', 'NN')]), ('of', 'IN'), Tree('NP', [('world-wide', 'JJ'), ('fame', 'NN')]), (',', ','), ('whose', 'WP$'), Tree('NP', [('friendship', 'NN')]), ('he', 'PRP'), ('had', 'VBD'), ('secured', 'VBN'), ('during', 'IN'), ('some', 'DT'), ('of', 'IN'), ('his', 'PRP$'), Tree('NP', [('great', 'JJ'), ('detective', 'JJ'), ('tours', 'NNS')]), ('and', 'CC'), Tree('NP', [('triumphs', 'NN')]), ('in', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('expecting', 'VBG'), ('Julius', 'NNP'), ('K.', 'NNP'), ('Brayne', 'NNP'), (',', ','), ('that', 'IN'), Tree('NP', [('multi-millionaire', 'NN')]), ('whose', 'WP$'), Tree('NP', [('colossal', 'NN')]), ('and', 'CC'), ('even', 'RB'), ('crushing', 'VBG'), Tree('NP', [('endowments', 'NNS')]), ('of', 'IN'), Tree('NP', [('small', 'JJ'), ('religions', 'NNS')]), ('have', 'VBP'), ('occasioned', 'VBN'), ('so', 'RB'), Tree('NP', [('much', 'JJ'), ('easy', 'JJ'), ('sport', 'NN')]), ('and', 'CC'), ('easier', 'JJR'), Tree('NP', [('solemnity', 'NN')]), ('for', 'IN'), ('the', 'DT'), ('American', 'NNP'), ('and', 'CC'), Tree('NP', [('English', 'JJ'), ('papers', 'NNS')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('Nobody', 'NN')]), ('could', 'MD'), ('quite', 'VB'), ('make', 'VB'), ('out', 'RP'), ('whether', 'IN'), ('Mr.', 'NNP'), ('Brayne', 'NNP'), ('was', 'VBD'), ('an', 'DT'), Tree('NP', [('atheist', 'NN')]), ('or', 'CC'), ('a', 'DT'), ('Mormon', 'NNP'), ('or', 'CC'), ('a', 'DT'), Tree('NP', [('Christian', 'JJ'), ('Scientist', 'NN')]), (';', ':'), ('but', 'CC'), ('he', 'PRP'), ('was', 'VBD'), ('ready', 'JJ'), ('to', 'TO'), ('pour', 'VB'), Tree('NP', [('money', 'NN')]), ('into', 'IN'), ('any', 'DT'), Tree('NP', [('intellectual', 'JJ'), ('vessel', 'NN')]), (',', ','), ('so', 'RB'), ('long', 'RB'), ('as', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('an', 'DT'), Tree('NP', [('untried', 'JJ'), ('vessel', 'NN')]), ('.', '.')]),
#  Tree('S', [('One', 'CD'), ('of', 'IN'), ('his', 'PRP$'), Tree('NP', [('hobbies', 'NNS')]), ('was', 'VBD'), ('to', 'TO'), ('wait', 'VB'), ('for', 'IN'), ('the', 'DT'), ('American', 'JJ'), ('Shakespeare—a', 'NNP'), Tree('NP', [('hobby', 'NN')]), ('more', 'RBR'), ('patient', 'JJ'), ('than', 'IN'), ('angling', 'VBG'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('admired', 'VBD'), ('Walt', 'NNP'), ('Whitman', 'NNP'), (',', ','), ('but', 'CC'), ('thought', 'VBD'), ('that', 'IN'), ('Luke', 'NNP'), ('P.', 'NNP'), ('Tanner', 'NNP'), (',', ','), ('of', 'IN'), ('Paris', 'NNP'), (',', ','), ('Pa.', 'NNP'), (',', ','), ('was', 'VBD'), ('more', 'RBR'), Tree('NP', [('“', 'JJ'), ('progressive', 'JJ'), ('”', 'NN')]), ('than', 'IN'), ('Whitman', 'NNP'), ('any', 'DT'), Tree('NP', [('day', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('liked', 'VBD'), Tree('NP', [('anything', 'NN')]), ('that', 'IN'), ('he', 'PRP'), ('thought', 'VBD'), ('“', 'NNP'), Tree('NP', [('progressive.', 'NN'), ('”', 'NN')]), ('He', 'PRP'), ('thought', 'VBD'), ('Valentin', 'NNP'), ('“', 'NNP'), Tree('NP', [('progressive', 'NN')]), (',', ','), ('”', 'NNP'), ('thereby', 'RB'), ('doing', 'VBG'), ('him', 'PRP'), ('a', 'DT'), Tree('NP', [('grave', 'NN'), ('injustice', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('solid', 'JJ'), ('appearance', 'NN')]), ('of', 'IN'), ('Julius', 'NNP'), ('K.', 'NNP'), ('Brayne', 'NNP'), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('room', 'NN')]), ('was', 'VBD'), ('as', 'RB'), ('decisive', 'JJ'), ('as', 'IN'), ('a', 'DT'), Tree('NP', [('dinner', 'NN'), ('bell', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('had', 'VBD'), ('this', 'DT'), Tree('NP', [('great', 'JJ'), ('quality', 'NN')]), (',', ','), ('which', 'WDT'), ('very', 'RB'), ('few', 'JJ'), ('of', 'IN'), ('us', 'PRP'), ('can', 'MD'), ('claim', 'VB'), (',', ','), ('that', 'IN'), ('his', 'PRP$'), Tree('NP', [('presence', 'NN')]), ('was', 'VBD'), ('as', 'RB'), ('big', 'JJ'), ('as', 'IN'), ('his', 'PRP$'), Tree('NP', [('absence', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('a', 'DT'), Tree('NP', [('huge', 'JJ'), ('fellow', 'NN')]), (',', ','), ('as', 'RB'), ('fat', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('was', 'VBD'), ('tall', 'JJ'), (',', ','), ('clad', 'JJ'), ('in', 'IN'), Tree('NP', [('complete', 'JJ'), ('evening', 'NN')]), ('black', 'JJ'), (',', ','), ('without', 'IN'), ('so', 'RB'), Tree('NP', [('much', 'JJ'), ('relief', 'NN')]), ('as', 'IN'), ('a', 'DT'), Tree('NP', [('watch-chain', 'NN')]), ('or', 'CC'), ('a', 'DT'), Tree('NP', [('ring', 'NN')]), ('.', '.')]),
#  Tree('S', [('His', 'PRP$'), Tree('NP', [('hair', 'NN')]), ('was', 'VBD'), ('white', 'JJ'), ('and', 'CC'), ('well', 'RB'), ('brushed', 'VBN'), ('back', 'RP'), ('like', 'IN'), ('a', 'DT'), Tree('NP', [('German', 'JJ'), ('’', 'NN'), ('s', 'NN')]), (';', ':'), ('his', 'PRP$'), Tree('NP', [('face', 'NN')]), ('was', 'VBD'), ('red', 'JJ'), (',', ','), ('fierce', 'JJ'), ('and', 'CC'), ('cherubic', 'JJ'), (',', ','), ('with', 'IN'), ('one', 'CD'), Tree('NP', [('dark', 'NN'), ('tuft', 'NN')]), ('under', 'IN'), ('the', 'DT'), ('lower', 'JJR'), Tree('NP', [('lip', 'NN')]), ('that', 'WDT'), ('threw', 'VBD'), ('up', 'RP'), ('that', 'IN'), ('otherwise', 'RB'), Tree('NP', [('infantile', 'JJ'), ('visage', 'NN')]), ('with', 'IN'), ('an', 'DT'), Tree('NP', [('effect', 'NN'), ('theatrical', 'NN')]), ('and', 'CC'), ('even', 'RB'), ('Mephistophelean', 'NNP'), ('.', '.')]),
#  Tree('S', [('Not', 'RB'), ('long', 'RB'), (',', ','), ('however', 'RB'), (',', ','), ('did', 'VBD'), ('that', 'IN'), Tree('NP', [('salon', 'NN')]), ('merely', 'RB'), Tree('NP', [('stare', 'NN')]), ('at', 'IN'), ('the', 'DT'), ('celebrated', 'JJ'), ('American', 'NNP'), (';', ':'), ('his', 'PRP$'), Tree('NP', [('lateness', 'NN')]), ('had', 'VBD'), ('already', 'RB'), ('become', 'VBN'), ('a', 'DT'), Tree('NP', [('domestic', 'JJ'), ('problem', 'NN')]), (',', ','), ('and', 'CC'), ('he', 'PRP'), ('was', 'VBD'), ('sent', 'VBN'), ('with', 'IN'), ('all', 'DT'), Tree('NP', [('speed', 'NN')]), ('into', 'IN'), ('the', 'DT'), Tree('NP', [('dining-room', 'NN')]), ('with', 'IN'), ('Lady', 'NNP'), ('Galloway', 'NNP'), ('on', 'IN'), ('his', 'PRP$'), Tree('NP', [('arm', 'NN')]), ('.', '.')]),
#  Tree('S', [('Except', 'IN'), ('on', 'IN'), ('one', 'CD'), Tree('NP', [('point', 'NN')]), ('the', 'DT'), ('Galloways', 'NNPS'), ('were', 'VBD'), ('genial', 'JJ'), ('and', 'CC'), ('casual', 'JJ'), ('enough', 'RB'), ('.', '.')]),
#  Tree('S', [('So', 'RB'), ('long', 'RB'), ('as', 'IN'), ('Lady', 'NNP'), ('Margaret', 'NNP'), ('did', 'VBD'), ('not', 'RB'), ('take', 'VB'), ('the', 'DT'), Tree('NP', [('arm', 'NN')]), ('of', 'IN'), ('that', 'DT'), Tree('NP', [('adventurer', 'NN')]), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), (',', ','), ('her', 'PRP$'), Tree('NP', [('father', 'NN')]), ('was', 'VBD'), ('quite', 'RB'), ('satisfied', 'JJ'), (';', ':'), ('and', 'CC'), ('she', 'PRP'), ('had', 'VBD'), ('not', 'RB'), ('done', 'VBN'), ('so', 'RB'), (',', ','), ('she', 'PRP'), ('had', 'VBD'), ('decorously', 'RB'), ('gone', 'VBN'), ('in', 'IN'), ('with', 'IN'), ('Dr.', 'NNP'), ('Simon', 'NNP'), ('.', '.')]),
#  Tree('S', [('Nevertheless', 'RB'), (',', ','), ('old', 'JJ'), ('Lord', 'NNP'), ('Galloway', 'NNP'), ('was', 'VBD'), Tree('NP', [('restless', 'NN')]), ('and', 'CC'), ('almost', 'RB'), Tree('NP', [('rude', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('diplomatic', 'JJ'), ('enough', 'RB'), ('during', 'IN'), Tree('NP', [('dinner', 'NN')]), (',', ','), ('but', 'CC'), ('when', 'WRB'), (',', ','), ('over', 'IN'), ('the', 'DT'), Tree('NP', [('cigars', 'NNS')]), (',', ','), ('three', 'CD'), ('of', 'IN'), ('the', 'DT'), ('younger', 'JJR'), ('men—Simon', 'VB'), ('the', 'DT'), Tree('NP', [('doctor', 'NN')]), (',', ','), ('Brown', 'NNP'), ('the', 'DT'), Tree('NP', [('priest', 'NN')]), (',', ','), ('and', 'CC'), ('the', 'DT'), ('detrimental', 'JJ'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), (',', ','), ('the', 'DT'), Tree('NP', [('exile', 'NN')]), ('in', 'IN'), ('a', 'DT'), Tree('NP', [('foreign', 'JJ'), ('uniform—all', 'NN')]), ('melted', 'VBD'), ('away', 'RB'), ('to', 'TO'), ('mix', 'VB'), ('with', 'IN'), ('the', 'DT'), Tree('NP', [('ladies', 'NNS')]), ('or', 'CC'), Tree('NP', [('smoke', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('conservatory', 'NN')]), (',', ','), ('then', 'RB'), ('the', 'DT'), ('English', 'NNP'), Tree('NP', [('diplomatist', 'NN')]), ('grew', 'VBD'), ('very', 'RB'), ('undiplomatic', 'JJ'), ('indeed', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('stung', 'JJ'), ('every', 'DT'), Tree('NP', [('sixty', 'NN')]), ('seconds', 'VBZ'), ('with', 'IN'), ('the', 'DT'), Tree('NP', [('thought', 'NN')]), ('that', 'IN'), ('the', 'DT'), Tree('NP', [('scamp', 'NN')]), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), ('might', 'MD'), ('be', 'VB'), ('signalling', 'VBG'), ('to', 'TO'), ('Margaret', 'NNP'), ('somehow', 'RB'), (';', ':'), ('he', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('attempt', 'VB'), ('to', 'TO'), ('imagine', 'VB'), ('how', 'WRB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('left', 'VBN'), ('over', 'RP'), ('the', 'DT'), Tree('NP', [('coffee', 'NN')]), ('with', 'IN'), ('Brayne', 'NNP'), (',', ','), ('the', 'DT'), Tree('NP', [('hoary', 'JJ'), ('Yankee', 'NN')]), ('who', 'WP'), ('believed', 'VBD'), ('in', 'IN'), ('all', 'DT'), Tree('NP', [('religions', 'NNS')]), (',', ','), ('and', 'CC'), ('Valentin', 'NNP'), (',', ','), ('the', 'DT'), ('grizzled', 'JJ'), ('Frenchman', 'NNP'), ('who', 'WP'), ('believed', 'VBD'), ('in', 'IN'), Tree('NP', [('none', 'NN')]), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('could', 'MD'), ('argue', 'VB'), ('with', 'IN'), ('each', 'DT'), ('other', 'JJ'), (',', ','), ('but', 'CC'), ('neither', 'DT'), ('could', 'MD'), ('appeal', 'VB'), ('to', 'TO'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('After', 'IN'), ('a', 'DT'), Tree('NP', [('time', 'NN')]), ('this', 'DT'), Tree('NP', [('“', 'JJ'), ('progressive', 'JJ'), ('”', 'NN'), ('logomachy', 'NN')]), ('had', 'VBD'), ('reached', 'VBN'), ('a', 'DT'), Tree('NP', [('crisis', 'NN')]), ('of', 'IN'), Tree('NP', [('tedium', 'NN')]), (';', ':'), ('Lord', 'NNP'), ('Galloway', 'NNP'), ('got', 'VBD'), ('up', 'RB'), ('also', 'RB'), ('and', 'CC'), ('sought', 'VBD'), ('the', 'DT'), Tree('NP', [('drawing-room', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('lost', 'VBD'), ('his', 'PRP$'), Tree('NP', [('way', 'NN')]), ('in', 'IN'), Tree('NP', [('long', 'JJ'), ('passages', 'NNS')]), ('for', 'IN'), ('some', 'DT'), ('six', 'CD'), ('or', 'CC'), ('eight', 'CD'), Tree('NP', [('minutes', 'NNS')]), (':', ':'), Tree('NP', [('till', 'NN')]), ('he', 'PRP'), ('heard', 'VBD'), ('the', 'DT'), ('high-pitched', 'JJ'), (',', ','), Tree('NP', [('didactic', 'JJ'), ('voice', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('doctor', 'NN')]), (',', ','), ('and', 'CC'), ('then', 'RB'), ('the', 'DT'), Tree('NP', [('dull', 'JJ'), ('voice', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('priest', 'NN')]), (',', ','), ('followed', 'VBN'), ('by', 'IN'), Tree('NP', [('general', 'JJ'), ('laughter', 'NN')]), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('also', 'RB'), (',', ','), ('he', 'PRP'), ('thought', 'VBD'), ('with', 'IN'), ('a', 'DT'), Tree('NP', [('curse', 'NN')]), (',', ','), ('were', 'VBD'), ('probably', 'RB'), ('arguing', 'VBG'), ('about', 'IN'), ('“', 'NNP'), Tree('NP', [('science', 'NN')]), ('and', 'CC'), Tree('NP', [('religion.', 'NN'), ('”', 'NN')]), ('But', 'CC'), ('the', 'DT'), Tree('NP', [('instant', 'NN')]), ('he', 'PRP'), ('opened', 'VBD'), ('the', 'DT'), Tree('NP', [('salon', 'NN'), ('door', 'NN')]), ('he', 'PRP'), ('saw', 'VBD'), ('only', 'RB'), ('one', 'CD'), Tree('NP', [('thing—he', 'NN')]), ('saw', 'VBD'), ('what', 'WP'), ('was', 'VBD'), ('not', 'RB'), ('there', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('saw', 'VBD'), ('that', 'IN'), ('Commandant', 'NNP'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), ('was', 'VBD'), ('absent', 'JJ'), (',', ','), ('and', 'CC'), ('that', 'IN'), ('Lady', 'NNP'), ('Margaret', 'NNP'), ('was', 'VBD'), ('absent', 'JJ'), ('too', 'RB'), ('.', '.')]),
#  Tree('S', [('Rising', 'VBG'), ('impatiently', 'RB'), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('drawing-room', 'NN')]), (',', ','), ('as', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('dining-room', 'NN')]), (',', ','), ('he', 'PRP'), ('stamped', 'VBD'), ('along', 'IN'), ('the', 'DT'), Tree('NP', [('passage', 'NN')]), ('once', 'RB'), ('more', 'RBR'), ('.', '.')]),
#  Tree('S', [('His', 'PRP$'), Tree('NP', [('notion', 'NN')]), ('of', 'IN'), ('protecting', 'VBG'), ('his', 'PRP$'), Tree('NP', [('daughter', 'NN')]), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('Irish-Algerian', 'JJ'), ('n', 'JJ'), ('’', 'JJ'), ('er-do-well', 'NN')]), ('had', 'VBD'), ('become', 'VBN'), Tree('NP', [('something', 'NN')]), ('central', 'JJ'), ('and', 'CC'), ('even', 'RB'), Tree('NP', [('mad', 'NNS')]), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('mind', 'NN')]), ('.', '.')]),
#  Tree('S', [('As', 'IN'), ('he', 'PRP'), ('went', 'VBD'), ('towards', 'IN'), ('the', 'DT'), Tree('NP', [('back', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('house', 'NN')]), (',', ','), ('where', 'WRB'), ('was', 'VBD'), ('Valentin', 'NNP'), ('’', 'NNP'), Tree('NP', [('s', 'NN'), ('study', 'NN')]), (',', ','), ('he', 'PRP'), ('was', 'VBD'), ('surprised', 'VBN'), ('to', 'TO'), ('meet', 'VB'), ('his', 'PRP$'), Tree('NP', [('daughter', 'NN')]), (',', ','), ('who', 'WP'), ('swept', 'VBD'), ('past', 'RB'), ('with', 'IN'), ('a', 'DT'), ('white', 'JJ'), (',', ','), Tree('NP', [('scornful', 'JJ'), ('face', 'NN')]), (',', ','), ('which', 'WDT'), ('was', 'VBD'), ('a', 'DT'), Tree('NP', [('second', 'JJ'), ('enigma', 'NN')]), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('she', 'PRP'), ('had', 'VBD'), ('been', 'VBN'), ('with', 'IN'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), (',', ','), ('where', 'WRB'), ('was', 'VBD'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), ('!', '.')]),
#  Tree('S', [('If', 'IN'), ('she', 'PRP'), ('had', 'VBD'), ('not', 'RB'), ('been', 'VBN'), ('with', 'IN'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), (',', ','), ('where', 'WRB'), ('had', 'VBD'), ('she', 'PRP'), ('been', 'VBN'), ('?', '.')]),
#  Tree('S', [('With', 'IN'), ('a', 'DT'), Tree('NP', [('sort', 'NN')]), ('of', 'IN'), Tree('NP', [('senile', 'NN')]), ('and', 'CC'), Tree('NP', [('passionate', 'NN'), ('suspicion', 'NN')]), ('he', 'PRP'), ('groped', 'VBD'), ('his', 'PRP$'), Tree('NP', [('way', 'NN')]), ('to', 'TO'), ('the', 'DT'), Tree('NP', [('dark', 'NN')]), ('back', 'RB'), Tree('NP', [('parts', 'NNS')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('mansion', 'NN')]), (',', ','), ('and', 'CC'), ('eventually', 'RB'), ('found', 'VBD'), ('a', 'DT'), Tree('NP', [('servants', 'NNS')]), Tree('NP', [('’', 'JJ'), ('entrance', 'NN')]), ('that', 'WDT'), ('opened', 'VBD'), ('on', 'IN'), ('to', 'TO'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('moon', 'NN')]), ('with', 'IN'), ('her', 'PRP$'), Tree('NP', [('scimitar', 'NN')]), ('had', 'VBD'), ('now', 'RB'), ('ripped', 'VBN'), ('up', 'RP'), ('and', 'CC'), ('rolled', 'VB'), ('away', 'RB'), ('all', 'PDT'), ('the', 'DT'), Tree('NP', [('storm-wrack', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('argent', 'NN'), ('light', 'NN')]), ('lit', 'VBD'), ('up', 'RP'), ('all', 'DT'), ('four', 'CD'), Tree('NP', [('corners', 'NNS')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('.', '.')]),
#  Tree('S', [('A', 'DT'), Tree('NP', [('tall', 'JJ'), ('figure', 'NN')]), ('in', 'IN'), Tree('NP', [('blue', 'NN')]), ('was', 'VBD'), ('striding', 'VBG'), ('across', 'IN'), ('the', 'DT'), Tree('NP', [('lawn', 'NN')]), ('towards', 'IN'), ('the', 'DT'), Tree('NP', [('study', 'NN'), ('door', 'NN')]), (';', ':'), ('a', 'DT'), Tree('NP', [('glint', 'NN')]), ('of', 'IN'), Tree('NP', [('moonlit', 'NN'), ('silver', 'NN')]), ('on', 'IN'), ('his', 'PRP$'), Tree('NP', [('facings', 'NNS')]), ('picked', 'VBD'), ('him', 'PRP'), ('out', 'RP'), ('as', 'IN'), ('Commandant', 'NNP'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('vanished', 'VBD'), ('through', 'IN'), ('the', 'DT'), Tree('NP', [('French', 'JJ'), ('windows', 'NNS')]), ('into', 'IN'), ('the', 'DT'), Tree('NP', [('house', 'NN')]), (',', ','), ('leaving', 'VBG'), ('Lord', 'NNP'), ('Galloway', 'NNP'), ('in', 'IN'), ('an', 'DT'), Tree('NP', [('indescribable', 'JJ'), ('temper', 'NN')]), (',', ','), ('at', 'IN'), ('once', 'RB'), ('virulent', 'JJ'), ('and', 'CC'), ('vague', 'JJ'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('blue-and-silver', 'JJ'), ('garden', 'NN')]), (',', ','), ('like', 'IN'), ('a', 'DT'), Tree('NP', [('scene', 'NN')]), ('in', 'IN'), ('a', 'DT'), Tree('NP', [('theatre', 'NN')]), (',', ','), ('seemed', 'VBD'), ('to', 'TO'), ('taunt', 'VB'), ('him', 'PRP'), ('with', 'IN'), ('all', 'PDT'), ('that', 'DT'), Tree('NP', [('tyrannic', 'JJ'), ('tenderness', 'NN')]), ('against', 'IN'), ('which', 'WDT'), ('his', 'PRP$'), Tree('NP', [('worldly', 'JJ'), ('authority', 'NN')]), ('was', 'VBD'), ('at', 'IN'), Tree('NP', [('war', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('length', 'NN')]), ('and', 'CC'), Tree('NP', [('grace', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('Irishman', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('stride', 'RB'), ('enraged', 'VBD'), ('him', 'PRP'), ('as', 'IN'), ('if', 'IN'), ('he', 'PRP'), ('were', 'VBD'), ('a', 'DT'), ('rival', 'JJ'), ('instead', 'RB'), ('of', 'IN'), ('a', 'DT'), Tree('NP', [('father', 'NN')]), (';', ':'), ('the', 'DT'), Tree('NP', [('moonlight', 'NN')]), ('maddened', 'VBD'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ('trapped', 'VBN'), ('as', 'IN'), ('if', 'IN'), ('by', 'IN'), Tree('NP', [('magic', 'NN')]), ('into', 'IN'), ('a', 'DT'), Tree('NP', [('garden', 'NN')]), ('of', 'IN'), Tree('NP', [('troubadours', 'NN')]), (',', ','), ('a', 'DT'), ('Watteau', 'NNP'), Tree('NP', [('fairyland', 'NN')]), (';', ':'), ('and', 'CC'), (',', ','), ('willing', 'JJ'), ('to', 'TO'), ('shake', 'VB'), ('off', 'RP'), Tree('NP', [('such', 'JJ'), ('amorous', 'JJ'), ('imbecilities', 'NNS')]), ('by', 'IN'), Tree('NP', [('speech', 'NN')]), (',', ','), ('he', 'PRP'), ('stepped', 'VBD'), ('briskly', 'RB'), ('after', 'IN'), ('his', 'PRP$'), Tree('NP', [('enemy', 'NN')]), ('.', '.')]),
#  Tree('S', [('As', 'IN'), ('he', 'PRP'), ('did', 'VBD'), ('so', 'RB'), ('he', 'PRP'), ('tripped', 'VBD'), ('over', 'IN'), ('some', 'DT'), Tree('NP', [('tree', 'NN')]), ('or', 'CC'), Tree('NP', [('stone', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('grass', 'NN')]), (';', ':'), ('looked', 'VBD'), ('down', 'RB'), ('at', 'IN'), ('it', 'PRP'), ('first', 'RB'), ('with', 'IN'), Tree('NP', [('irritation', 'NN')]), ('and', 'CC'), ('then', 'RB'), ('a', 'DT'), Tree('NP', [('second', 'JJ'), ('time', 'NN')]), ('with', 'IN'), Tree('NP', [('curiosity', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('next', 'JJ'), ('instant', 'NN')]), ('the', 'DT'), Tree('NP', [('moon', 'NN')]), ('and', 'CC'), ('the', 'DT'), Tree('NP', [('tall', 'JJ'), ('poplars', 'NNS')]), ('looked', 'VBD'), ('at', 'IN'), ('an', 'DT'), Tree('NP', [('unusual', 'JJ'), ('sight—an', 'NN')]), Tree('NP', [('elderly', 'JJ'), ('English', 'JJ'), ('diplomatist', 'NN')]), ('running', 'VBG'), ('hard', 'JJ'), ('and', 'CC'), ('crying', 'VBG'), ('or', 'CC'), ('bellowing', 'VBG'), ('as', 'IN'), ('he', 'PRP'), ('ran', 'VBD'), ('.', '.')]),
#  Tree('S', [('His', 'PRP$'), Tree('NP', [('hoarse', 'NN')]), ('shouts', 'VBZ'), ('brought', 'VBD'), ('a', 'DT'), Tree('NP', [('pale', 'JJ'), ('face', 'NN')]), ('to', 'TO'), ('the', 'DT'), Tree('NP', [('study', 'NN'), ('door', 'NN')]), (',', ','), ('the', 'DT'), Tree('NP', [('beaming', 'NN')]), Tree('NP', [('glasses', 'NNS')]), ('and', 'CC'), Tree('NP', [('worried', 'JJ'), ('brow', 'NN')]), ('of', 'IN'), ('Dr.', 'NNP'), ('Simon', 'NNP'), (',', ','), ('who', 'WP'), ('heard', 'VBD'), ('the', 'DT'), ('nobleman', 'JJ'), ('’', 'NNP'), Tree('NP', [('s', 'NN')]), ('first', 'RB'), Tree('NP', [('clear', 'JJ'), ('words', 'NNS')]), ('.', '.')]),
#  Tree('S', [('Lord', 'NNP'), ('Galloway', 'NNP'), ('was', 'VBD'), ('crying', 'VBG'), (':', ':'), ('“', 'VB'), ('A', 'DT'), Tree('NP', [('corpse', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('grass—a', 'JJ'), ('blood-stained', 'JJ'), ('corpse.', 'NN')]), ('”', 'NNP'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), ('at', 'IN'), ('last', 'JJ'), ('had', 'VBD'), ('gone', 'VBN'), ('utterly', 'RB'), ('out', 'IN'), ('of', 'IN'), ('his', 'PRP$'), Tree('NP', [('mind', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('We', 'PRP'), ('must', 'MD'), ('tell', 'VB'), ('Valentin', 'NNP'), ('at', 'IN'), ('once', 'RB'), (',', ','), ('”', 'NNP'), ('said', 'VBD'), ('the', 'DT'), Tree('NP', [('doctor', 'NN')]), (',', ','), ('when', 'WRB'), ('the', 'DT'), ('other', 'JJ'), ('had', 'VBD'), ('brokenly', 'RB'), ('described', 'VBN'), ('all', 'PDT'), ('that', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('dared', 'VBN'), ('to', 'TO'), ('examine', 'VB'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('It', 'PRP'), ('is', 'VBZ'), ('fortunate', 'JJ'), ('that', 'IN'), ('he', 'PRP'), ('is', 'VBZ'), ('here', 'RB'), (';', ':'), ('”', 'NNP'), ('and', 'CC'), ('even', 'RB'), ('as', 'IN'), ('he', 'PRP'), ('spoke', 'VBD'), ('the', 'DT'), Tree('NP', [('great', 'JJ'), ('detective', 'NN')]), ('entered', 'VBD'), ('the', 'DT'), Tree('NP', [('study', 'NN')]), (',', ','), ('attracted', 'VBN'), ('by', 'IN'), ('the', 'DT'), Tree('NP', [('cry', 'NN')]), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('almost', 'RB'), ('amusing', 'VBG'), ('to', 'TO'), ('note', 'VB'), ('his', 'PRP$'), Tree('NP', [('typical', 'JJ'), ('transformation', 'NN')]), (';', ':'), ('he', 'PRP'), ('had', 'VBD'), ('come', 'VBN'), ('with', 'IN'), ('the', 'DT'), Tree('NP', [('common', 'JJ'), ('concern', 'NN')]), ('of', 'IN'), ('a', 'DT'), Tree('NP', [('host', 'NN')]), ('and', 'CC'), ('a', 'DT'), Tree('NP', [('gentleman', 'NN')]), (',', ','), ('fearing', 'VBG'), ('that', 'IN'), ('some', 'DT'), Tree('NP', [('guest', 'NN')]), ('or', 'CC'), Tree('NP', [('servant', 'NN')]), ('was', 'VBD'), ('ill', 'RB'), ('.', '.')]),
#  Tree('S', [('When', 'WRB'), ('he', 'PRP'), ('was', 'VBD'), ('told', 'VBN'), ('the', 'DT'), Tree('NP', [('gory', 'NN'), ('fact', 'NN')]), (',', ','), ('he', 'PRP'), ('turned', 'VBD'), ('with', 'IN'), ('all', 'DT'), ('his', 'PRP$'), Tree('NP', [('gravity', 'NN')]), ('instantly', 'RB'), ('bright', 'JJ'), ('and', 'CC'), Tree('NP', [('businesslike', 'NN')]), (';', ':'), ('for', 'IN'), ('this', 'DT'), (',', ','), ('however', 'RB'), ('abrupt', 'JJ'), ('and', 'CC'), ('awful', 'JJ'), (',', ','), ('was', 'VBD'), ('his', 'PRP$'), Tree('NP', [('business', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('Strange', 'NNP'), (',', ','), Tree('NP', [('gentlemen', 'NNS')]), (',', ','), Tree('NP', [('”', 'NN')]), ('he', 'PRP'), ('said', 'VBD'), ('as', 'IN'), ('they', 'PRP'), ('hurried', 'VBD'), ('out', 'RP'), ('into', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), (',', ','), ('“', 'VBP'), ('that', 'IN'), ('I', 'PRP'), ('should', 'MD'), ('have', 'VB'), ('hunted', 'VBN'), Tree('NP', [('mysteries', 'NNS')]), ('all', 'DT'), ('over', 'IN'), ('the', 'DT'), Tree('NP', [('earth', 'NN')]), (',', ','), ('and', 'CC'), ('now', 'RB'), ('one', 'CD'), ('comes', 'VBZ'), ('and', 'CC'), Tree('NP', [('settles', 'NNS')]), ('in', 'IN'), ('my', 'PRP$'), Tree('NP', [('own', 'JJ'), ('back-yard', 'NN')]), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('where', 'WRB'), ('is', 'VBZ'), ('the', 'DT'), Tree('NP', [('place', 'NN')]), ('?', '.'), ('”', 'IN'), ('They', 'PRP'), ('crossed', 'VBD'), ('the', 'DT'), Tree('NP', [('lawn', 'NN')]), ('less', 'JJR'), ('easily', 'RB'), (',', ','), ('as', 'IN'), ('a', 'DT'), Tree('NP', [('slight', 'JJ'), ('mist', 'NN')]), ('had', 'VBD'), ('begun', 'VBN'), ('to', 'TO'), ('rise', 'VB'), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('river', 'NN')]), (';', ':'), ('but', 'CC'), ('under', 'IN'), ('the', 'DT'), Tree('NP', [('guidance', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('shaken', 'VBN'), ('Galloway', 'NNP'), ('they', 'PRP'), ('found', 'VBD'), ('the', 'DT'), Tree('NP', [('body', 'NN')]), ('sunken', 'VBZ'), ('in', 'IN'), Tree('NP', [('deep', 'JJ'), ('grass—the', 'NN'), ('body', 'NN')]), ('of', 'IN'), ('a', 'DT'), ('very', 'RB'), ('tall', 'JJ'), ('and', 'CC'), Tree('NP', [('broad-shouldered', 'JJ'), ('man', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('lay', 'VBD'), Tree('NP', [('face', 'NN')]), Tree('NP', [('downwards', 'NNS')]), (',', ','), ('so', 'IN'), ('they', 'PRP'), ('could', 'MD'), ('only', 'RB'), ('see', 'VB'), ('that', 'IN'), ('his', 'PRP$'), Tree('NP', [('big', 'JJ'), ('shoulders', 'NNS')]), ('were', 'VBD'), ('clad', 'VBN'), ('in', 'IN'), Tree('NP', [('black', 'JJ'), ('cloth', 'NN')]), (',', ','), ('and', 'CC'), ('that', 'IN'), ('his', 'PRP$'), Tree('NP', [('big', 'JJ'), ('head', 'NN')]), ('was', 'VBD'), ('bald', 'JJ'), (',', ','), ('except', 'IN'), ('for', 'IN'), ('a', 'DT'), Tree('NP', [('wisp', 'NN')]), ('or', 'CC'), ('two', 'CD'), ('of', 'IN'), Tree('NP', [('brown', 'JJ'), ('hair', 'NN')]), ('that', 'WDT'), Tree('NP', [('clung', 'NN')]), ('to', 'TO'), ('his', 'PRP$'), Tree('NP', [('skull', 'NN')]), ('like', 'IN'), Tree('NP', [('wet', 'JJ'), ('seaweed', 'NN')]), ('.', '.')]),
#  Tree('S', [('A', 'DT'), Tree('NP', [('scarlet', 'JJ'), ('serpent', 'NN')]), ('of', 'IN'), Tree('NP', [('blood', 'NN')]), ('crawled', 'VBN'), ('from', 'IN'), ('under', 'IN'), ('his', 'PRP$'), Tree('NP', [('fallen', 'JJ'), ('face', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('At', 'IN'), ('least', 'JJS'), (',', ','), ('”', 'NNP'), ('said', 'VBD'), ('Simon', 'NNP'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('deep', 'JJ'), ('and', 'CC'), Tree('NP', [('singular', 'JJ'), ('intonation', 'NN')]), (',', ','), Tree('NP', [('“', 'NN')]), ('he', 'PRP'), ('is', 'VBZ'), Tree('NP', [('none', 'NN')]), ('of', 'IN'), ('our', 'PRP$'), Tree('NP', [('party.', 'NN')]), ('”', 'NNP'), ('“', 'NNP'), ('Examine', 'NNP'), ('him', 'PRP'), (',', ','), Tree('NP', [('doctor', 'NN')]), (',', ','), ('”', 'NNP'), ('cried', 'VBD'), ('Valentin', 'NNP'), ('rather', 'RB'), ('sharply', 'RB'), ('.', '.')]),
#  Tree('S', [('“', 'IN'), ('He', 'PRP'), ('may', 'MD'), ('not', 'RB'), ('be', 'VB'), ('dead.', 'JJ'), ('”', 'IN'), ('The', 'DT'), Tree('NP', [('doctor', 'NN')]), ('bent', 'VBD'), ('down', 'RB'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('He', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('quite', 'RB'), ('cold', 'JJ'), (',', ','), ('but', 'CC'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ'), ('he', 'PRP'), ('is', 'VBZ'), ('dead', 'JJ'), ('enough', 'RB'), (',', ','), ('”', 'VBZ'), ('he', 'PRP'), ('answered', 'VBD'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('Just', 'NNP'), ('help', 'VB'), ('me', 'PRP'), ('to', 'TO'), ('lift', 'VB'), ('him', 'PRP'), Tree('NP', [('up.', 'JJ'), ('”', 'NN')]), ('They', 'PRP'), ('lifted', 'VBD'), ('him', 'PRP'), ('carefully', 'RB'), ('an', 'DT'), Tree('NP', [('inch', 'NN')]), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('ground', 'NN')]), (',', ','), ('and', 'CC'), ('all', 'DT'), Tree('NP', [('doubts', 'NNS')]), ('as', 'IN'), ('to', 'TO'), ('his', 'PRP$'), ('being', 'VBG'), ('really', 'RB'), ('dead', 'JJ'), ('were', 'VBD'), ('settled', 'VBN'), ('at', 'IN'), ('once', 'RB'), ('and', 'CC'), ('frightfully', 'RB'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('head', 'NN')]), ('fell', 'VBD'), ('away', 'RB'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('had', 'VBD'), ('been', 'VBN'), ('entirely', 'RB'), ('sundered', 'VBN'), ('from', 'IN'), ('the', 'DT'), Tree('NP', [('body', 'NN')]), (';', ':'), ('whoever', 'WDT'), ('had', 'VBD'), ('cut', 'VBN'), ('his', 'PRP$'), Tree('NP', [('throat', 'NN')]), ('had', 'VBD'), ('managed', 'VBN'), ('to', 'TO'), ('sever', 'VB'), ('the', 'DT'), Tree('NP', [('neck', 'NN')]), ('as', 'RB'), ('well', 'RB'), ('.', '.')]),
#  Tree('S', [('Even', 'RB'), ('Valentin', 'NNP'), ('was', 'VBD'), ('slightly', 'RB'), ('shocked', 'VBN'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('He', 'PRP'), ('must', 'MD'), ('have', 'VB'), ('been', 'VBN'), ('as', 'RB'), ('strong', 'JJ'), ('as', 'IN'), ('a', 'DT'), Tree('NP', [('gorilla', 'NN')]), (',', ','), ('”', 'CC'), ('he', 'PRP'), ('muttered', 'VBD'), ('.', '.')]),
#  Tree('S', [('Not', 'RB'), ('without', 'IN'), ('a', 'DT'), Tree('NP', [('shiver', 'NN')]), (',', ','), ('though', 'IN'), ('he', 'PRP'), ('was', 'VBD'), ('used', 'VBN'), ('to', 'TO'), Tree('NP', [('anatomical', 'JJ'), ('abortions', 'NNS')]), (',', ','), ('Dr.', 'NNP'), ('Simon', 'NNP'), ('lifted', 'VBD'), ('the', 'DT'), Tree('NP', [('head', 'NN')]), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('slightly', 'RB'), ('slashed', 'VBN'), ('about', 'IN'), ('the', 'DT'), Tree('NP', [('neck', 'NN')]), ('and', 'CC'), Tree('NP', [('jaw', 'NN')]), (',', ','), ('but', 'CC'), ('the', 'DT'), Tree('NP', [('face', 'NN')]), ('was', 'VBD'), ('substantially', 'RB'), ('unhurt', 'JJ'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('ponderous', 'JJ'), (',', ','), Tree('NP', [('yellow', 'JJ'), ('face', 'NN')]), (',', ','), ('at', 'IN'), ('once', 'RB'), ('sunken', 'VBN'), ('and', 'CC'), ('swollen', 'VBN'), (',', ','), ('with', 'IN'), ('a', 'DT'), Tree('NP', [('hawk-like', 'JJ'), ('nose', 'NN')]), ('and', 'CC'), Tree('NP', [('heavy', 'JJ'), ('lids—a', 'JJ'), ('face', 'NN')]), ('of', 'IN'), ('a', 'DT'), ('wicked', 'JJ'), ('Roman', 'NNP'), Tree('NP', [('emperor', 'NN')]), (',', ','), ('with', 'IN'), (',', ','), ('perhaps', 'RB'), (',', ','), ('a', 'DT'), Tree('NP', [('distant', 'JJ'), ('touch', 'NN')]), ('of', 'IN'), ('a', 'DT'), Tree('NP', [('Chinese', 'JJ'), ('emperor', 'NN')]), ('.', '.')]),
#  Tree('S', [('All', 'DT'), ('present', 'JJ'), ('seemed', 'VBD'), ('to', 'TO'), ('look', 'VB'), ('at', 'IN'), ('it', 'PRP'), ('with', 'IN'), ('the', 'DT'), ('coldest', 'JJS'), Tree('NP', [('eye', 'NN')]), ('of', 'IN'), Tree('NP', [('ignorance', 'NN')]), ('.', '.')]),
# ...
#  Tree('S', [('A', 'DT'), Tree('NP', [('voice', 'NN')]), ('older', 'JJR'), ('than', 'IN'), ('his', 'PRP$'), Tree('NP', [('first', 'JJ'), ('fathers', 'NNS')]), ('seemed', 'VBD'), ('saying', 'VBG'), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('ear', 'NN')]), (':', ':'), ('“', 'JJ'), ('Keep', 'NNP'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('monstrous', 'JJ'), ('garden', 'NN')]), ('where', 'WRB'), ('grows', 'VBZ'), ('the', 'DT'), Tree('NP', [('tree', 'NN')]), ('with', 'IN'), Tree('NP', [('double', 'JJ'), ('fruit', 'NN')]), ('.', '.')]),
#  Tree('S', [('Avoid', 'IN'), ('the', 'DT'), Tree('NP', [('evil', 'JJ'), ('garden', 'NN')]), ('where', 'WRB'), ('died', 'VBD'), ('the', 'DT'), Tree('NP', [('man', 'NN')]), ('with', 'IN'), ('two', 'CD'), Tree('NP', [('heads.', 'NNS')]), ('”', 'VBP'), ('Yet', 'RB'), (',', ','), ('while', 'IN'), ('these', 'DT'), Tree('NP', [('shameful', 'JJ'), ('symbolic', 'JJ'), ('shapes', 'NNS')]), ('passed', 'VBN'), ('across', 'IN'), ('the', 'DT'), Tree('NP', [('ancient', 'JJ'), ('mirror', 'NN')]), ('of', 'IN'), ('his', 'PRP$'), Tree('NP', [('Irish', 'JJ'), ('soul', 'NN')]), (',', ','), ('his', 'PRP$'), ('Frenchified', 'NNP'), Tree('NP', [('intellect', 'NN')]), ('was', 'VBD'), ('quite', 'RB'), ('alert', 'JJ'), (',', ','), ('and', 'CC'), ('was', 'VBD'), ('watching', 'VBG'), ('the', 'DT'), Tree('NP', [('odd', 'JJ'), ('priest', 'NN')]), ('as', 'IN'), ('closely', 'RB'), ('and', 'CC'), ('incredulously', 'RB'), ('as', 'IN'), ('all', 'PDT'), ('the', 'DT'), Tree('NP', [('rest', 'NN')]), ('.', '.')]),
#  Tree('S', [('Father', 'NNP'), ('Brown', 'NNP'), ('had', 'VBD'), ('turned', 'VBN'), Tree('NP', [('round', 'NN')]), ('at', 'IN'), ('last', 'JJ'), (',', ','), ('and', 'CC'), ('stood', 'VBD'), ('against', 'IN'), ('the', 'DT'), Tree('NP', [('window', 'NN')]), (',', ','), ('with', 'IN'), ('his', 'PRP$'), Tree('NP', [('face', 'NN')]), ('in', 'IN'), Tree('NP', [('dense', 'JJ'), ('shadow', 'NN')]), (';', ':'), ('but', 'CC'), ('even', 'RB'), ('in', 'IN'), ('that', 'DT'), Tree('NP', [('shadow', 'NN')]), ('they', 'PRP'), ('could', 'MD'), ('see', 'VB'), ('it', 'PRP'), ('was', 'VBD'), ('pale', 'JJ'), ('as', 'IN'), Tree('NP', [('ashes', 'NNS')]), ('.', '.')]),
#  Tree('S', [('Nevertheless', 'RB'), (',', ','), ('he', 'PRP'), ('spoke', 'VBD'), ('quite', 'RB'), ('sensibly', 'RB'), (',', ','), ('as', 'IN'), ('if', 'IN'), ('there', 'EX'), ('were', 'VBD'), ('no', 'DT'), ('Gaelic', 'NNP'), Tree('NP', [('souls', 'NNS')]), ('on', 'IN'), Tree('NP', [('earth', 'NN')]), ('.', '.')]),
#  Tree('S', [('“', 'JJ'), ('Gentlemen', 'NNP'), (',', ','), ('”', 'NNP'), ('he', 'PRP'), ('said', 'VBD'), (',', ','), ('“', 'NNP'), ('you', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('find', 'VB'), ('the', 'DT'), Tree('NP', [('strange', 'JJ'), ('body', 'NN')]), ('of', 'IN'), ('Becker', 'NNP'), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('find', 'VB'), ('any', 'DT'), Tree('NP', [('strange', 'JJ'), ('body', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('garden', 'NN')]), ('.', '.')]),
#  Tree('S', [('In', 'IN'), Tree('NP', [('face', 'NN')]), ('of', 'IN'), ('Dr.', 'NNP'), ('Simon', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), Tree('NP', [('rationalism', 'NN')]), (',', ','), ('I', 'PRP'), ('still', 'RB'), ('affirm', 'VBP'), ('that', 'IN'), ('Becker', 'NNP'), ('was', 'VBD'), ('only', 'RB'), ('partly', 'RB'), ('present', 'JJ'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('Look', 'NN')]), ('here', 'RB'), ('!', '.'), Tree('NP', [('”', 'NN')]), ('(', '('), ('pointing', 'VBG'), ('to', 'TO'), ('the', 'DT'), Tree('NP', [('black', 'JJ'), ('bulk', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('mysterious', 'JJ'), ('corpse', 'NN')]), (')', ')'), Tree('NP', [('“', 'NN')]), ('you', 'PRP'), ('never', 'RB'), ('saw', 'VBD'), ('that', 'IN'), Tree('NP', [('man', 'NN')]), ('in', 'IN'), ('your', 'PRP$'), Tree('NP', [('lives', 'NNS')]), ('.', '.')]),
#  Tree('S', [('Did', 'NNP'), ('you', 'PRP'), ('ever', 'RB'), ('see', 'VB'), ('this', 'DT'), Tree('NP', [('man', 'NN')]), ('?', '.'), ('”', 'CC'), ('He', 'PRP'), ('rapidly', 'RB'), ('rolled', 'VBD'), ('away', 'RP'), ('the', 'DT'), Tree('NP', [('bald', 'NN')]), (',', ','), Tree('NP', [('yellow', 'JJ'), ('head', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('unknown', 'JJ'), (',', ','), ('and', 'CC'), ('put', 'VBD'), ('in', 'IN'), ('its', 'PRP$'), Tree('NP', [('place', 'NN')]), ('the', 'DT'), Tree('NP', [('white-', 'NN')]), ('maned', 'VBD'), Tree('NP', [('head', 'NN')]), ('beside', 'IN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('there', 'EX'), (',', ','), ('complete', 'JJ'), (',', ','), ('unified', 'JJ'), (',', ','), ('unmistakable', 'JJ'), (',', ','), ('lay', 'VBD'), ('Julius', 'NNP'), ('K.', 'NNP'), ('Brayne', 'NNP'), ('.', '.')]),
#  Tree('S', [('“', 'IN'), ('The', 'DT'), Tree('NP', [('murderer', 'NN')]), (',', ','), ('”', 'NNP'), ('went', 'VBD'), ('on', 'IN'), ('Brown', 'NNP'), ('quietly', 'RB'), (',', ','), ('“', 'NNP'), ('hacked', 'VBD'), ('off', 'RP'), ('his', 'PRP$'), Tree('NP', [('enemy', 'NN')]), ('’', 'NNP'), ('s', 'VBZ'), Tree('NP', [('head', 'NN')]), ('and', 'CC'), ('flung', 'VBD'), ('the', 'DT'), Tree('NP', [('sword', 'NN')]), ('far', 'RB'), ('over', 'IN'), ('the', 'DT'), Tree('NP', [('wall', 'NN')]), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('he', 'PRP'), ('was', 'VBD'), ('too', 'RB'), ('clever', 'JJ'), ('to', 'TO'), ('fling', 'VBG'), ('the', 'DT'), Tree('NP', [('sword', 'NN')]), ('only', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('flung', 'VBD'), ('the', 'DT'), Tree('NP', [('head', 'NN')]), ('over', 'IN'), ('the', 'DT'), Tree('NP', [('wall', 'NN')]), ('also', 'RB'), ('.', '.')]),
#  Tree('S', [('Then', 'RB'), ('he', 'PRP'), ('had', 'VBD'), ('only', 'RB'), ('to', 'TO'), ('clap', 'VB'), ('on', 'IN'), ('another', 'DT'), Tree('NP', [('head', 'NN')]), ('to', 'TO'), ('the', 'DT'), Tree('NP', [('corpse', 'NN')]), (',', ','), ('and', 'CC'), ('(', '('), ('as', 'IN'), ('he', 'PRP'), ('insisted', 'VBD'), ('on', 'IN'), ('a', 'DT'), Tree('NP', [('private', 'JJ'), ('inquest', 'NN')]), (')', ')'), ('you', 'PRP'), ('all', 'DT'), ('imagined', 'VBD'), ('a', 'DT'), ('totally', 'RB'), Tree('NP', [('new', 'JJ'), ('man.', 'NN')]), ('”', 'NNP'), ('“', 'NNP'), ('Clap', 'NNP'), ('on', 'IN'), ('another', 'DT'), Tree('NP', [('head', 'NN')]), ('!', '.'), Tree('NP', [('”', 'NN')]), ('said', 'VBD'), ('O', 'NNP'), ('’', 'NNP'), ('Brien', 'NNP'), Tree('NP', [('staring', 'NN')]), ('.', '.')]),
#  Tree('S', [('“', 'VB'), ('What', 'WP'), Tree('NP', [('other', 'JJ'), ('head', 'NN')]), ('?', '.')]),
#  Tree('S', [('Heads', 'NNP'), ('don', 'VBZ'), Tree('NP', [('’', 'JJ'), ('t', 'NN'), ('grow', 'NN')]), ('on', 'IN'), Tree('NP', [('garden', 'NN')]), Tree('NP', [('bushes', 'NNS')]), (',', ','), ('do', 'VBP'), ('they', 'PRP'), ('?', '.'), ('”', "''"), ('“', 'VBZ'), ('No', 'NNP'), (',', ','), ('”', 'NNP'), ('said', 'VBD'), ('Father', 'NNP'), ('Brown', 'NNP'), ('huskily', 'RB'), (',', ','), ('and', 'CC'), ('looking', 'VBG'), ('at', 'IN'), ('his', 'PRP$'), Tree('NP', [('boots', 'NNS')]), (';', ':'), ('“', 'NNP'), ('there', 'EX'), ('is', 'VBZ'), ('only', 'RB'), ('one', 'CD'), Tree('NP', [('place', 'NN')]), ('where', 'WRB'), ('they', 'PRP'), ('grow', 'VBP'), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('grow', 'VBP'), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('basket', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('guillotine', 'NN')]), (',', ','), Tree('NP', [('beside', 'NN')]), ('which', 'WDT'), ('the', 'DT'), Tree('NP', [('chief', 'NN')]), ('of', 'IN'), Tree('NP', [('police', 'NN')]), (',', ','), ('Aristide', 'NNP'), ('Valentin', 'NNP'), (',', ','), ('was', 'VBD'), ('standing', 'VBG'), ('not', 'RB'), ('an', 'DT'), Tree('NP', [('hour', 'NN')]), ('before', 'IN'), ('the', 'DT'), Tree('NP', [('murder', 'NN')]), ('.', '.')]),
#  Tree('S', [('Oh', 'UH'), (',', ','), ('my', 'PRP$'), Tree('NP', [('friends', 'NNS')]), (',', ','), ('hear', 'VBP'), ('me', 'PRP'), ('a', 'DT'), Tree('NP', [('minute', 'NN')]), ('more', 'JJR'), ('before', 'IN'), ('you', 'PRP'), ('tear', 'VBP'), ('me', 'PRP'), ('in', 'IN'), Tree('NP', [('pieces', 'NNS')]), ('.', '.')]),
#  Tree('S', [('Valentin', 'NNP'), ('is', 'VBZ'), ('an', 'DT'), Tree('NP', [('honest', 'JJ'), ('man', 'NN')]), (',', ','), ('if', 'IN'), ('being', 'VBG'), Tree('NP', [('mad', 'NN')]), ('for', 'IN'), ('an', 'DT'), Tree('NP', [('arguable', 'JJ'), ('cause', 'NN')]), ('is', 'VBZ'), ('honesty', 'JJ'), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('did', 'VBD'), ('you', 'PRP'), ('never', 'RB'), ('see', 'VBP'), ('in', 'IN'), ('that', 'DT'), Tree('NP', [('cold', 'NN')]), (',', ','), Tree('NP', [('grey', 'JJ'), ('eye', 'NN')]), ('of', 'IN'), ('his', 'PRP$'), ('that', 'IN'), ('he', 'PRP'), ('is', 'VBZ'), ('mad', 'JJ'), ('!', '.')]),
#  Tree('S', [('He', 'PRP'), ('would', 'MD'), ('do', 'VB'), Tree('NP', [('anything', 'NN')]), (',', ','), Tree('NP', [('anything', 'NN')]), (',', ','), ('to', 'TO'), ('break', 'VB'), ('what', 'WP'), ('he', 'PRP'), ('calls', 'VBZ'), ('the', 'DT'), Tree('NP', [('superstition', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('Cross', 'NNP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('has', 'VBZ'), ('fought', 'VBN'), ('for', 'IN'), ('it', 'PRP'), ('and', 'CC'), ('starved', 'VBD'), ('for', 'IN'), ('it', 'PRP'), (',', ','), ('and', 'CC'), ('now', 'RB'), ('he', 'PRP'), ('has', 'VBZ'), ('murdered', 'VBN'), ('for', 'IN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('Brayne', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), Tree('NP', [('crazy', 'JJ'), ('millions', 'NNS')]), ('had', 'VBD'), ('hitherto', 'VBN'), ('been', 'VBN'), ('scattered', 'VBN'), ('among', 'IN'), ('so', 'RB'), Tree('NP', [('many', 'JJ'), ('sects', 'NNS')]), ('that', 'IN'), ('they', 'PRP'), ('did', 'VBD'), ('little', 'JJ'), ('to', 'TO'), ('alter', 'VB'), ('the', 'DT'), Tree('NP', [('balance', 'NN')]), ('of', 'IN'), Tree('NP', [('things', 'NNS')]), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('Valentin', 'NNP'), ('heard', 'VBD'), ('a', 'DT'), Tree('NP', [('whisper', 'NN')]), ('that', 'WDT'), ('Brayne', 'NNP'), (',', ','), ('like', 'IN'), ('so', 'RB'), Tree('NP', [('many', 'JJ'), ('scatter-brained', 'JJ'), ('sceptics', 'NNS')]), (',', ','), ('was', 'VBD'), ('drifting', 'VBG'), ('to', 'TO'), ('us', 'PRP'), (';', ':'), ('and', 'CC'), ('that', 'DT'), ('was', 'VBD'), ('quite', 'RB'), ('a', 'DT'), Tree('NP', [('different', 'JJ'), ('thing', 'NN')]), ('.', '.')]),
#  Tree('S', [('Brayne', 'NNP'), ('would', 'MD'), ('pour', 'VB'), Tree('NP', [('supplies', 'NNS')]), ('into', 'IN'), ('the', 'DT'), ('impoverished', 'JJ'), ('and', 'CC'), ('pugnacious', 'JJ'), ('Church', 'NNP'), ('of', 'IN'), ('France', 'NNP'), (';', ':'), ('he', 'PRP'), ('would', 'MD'), ('support', 'VB'), ('six', 'CD'), ('Nationalist', 'NNP'), Tree('NP', [('newspapers', 'NNS')]), ('like', 'IN'), ('The', 'DT'), ('Guillotine', 'NNP'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('battle', 'NN')]), ('was', 'VBD'), ('already', 'RB'), ('balanced', 'VBN'), ('on', 'IN'), ('a', 'DT'), Tree('NP', [('point', 'NN')]), (',', ','), ('and', 'CC'), ('the', 'DT'), ('fanatic', 'JJ'), ('took', 'VBD'), Tree('NP', [('flame', 'NN')]), ('at', 'IN'), ('the', 'DT'), Tree('NP', [('risk', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('resolved', 'VBD'), ('to', 'TO'), ('destroy', 'VB'), ('the', 'DT'), Tree('NP', [('millionaire', 'NN')]), (',', ','), ('and', 'CC'), ('he', 'PRP'), ('did', 'VBD'), ('it', 'PRP'), ('as', 'IN'), ('one', 'CD'), ('would', 'MD'), ('expect', 'VB'), ('the', 'DT'), ('greatest', 'JJS'), ('of', 'IN'), Tree('NP', [('detectives', 'NNS')]), ('to', 'TO'), ('commit', 'VB'), ('his', 'PRP$'), Tree('NP', [('only', 'JJ'), ('crime', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('abstracted', 'VBD'), ('the', 'DT'), Tree('NP', [('severed', 'JJ'), ('head', 'NN')]), ('of', 'IN'), ('Becker', 'NNP'), ('on', 'IN'), ('some', 'DT'), Tree('NP', [('criminological', 'JJ'), ('excuse', 'NN')]), (',', ','), ('and', 'CC'), ('took', 'VBD'), ('it', 'PRP'), Tree('NP', [('home', 'NN')]), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('official', 'NN'), ('box', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('had', 'VBD'), ('that', 'IN'), Tree('NP', [('last', 'JJ'), ('argument', 'NN')]), ('with', 'IN'), ('Brayne', 'NNP'), (',', ','), ('that', 'IN'), ('Lord', 'NNP'), ('Galloway', 'NNP'), ('did', 'VBD'), ('not', 'RB'), ('hear', 'VB'), ('the', 'DT'), Tree('NP', [('end', 'NN')]), ('of', 'IN'), (';', ':'), ('that', 'IN'), ('failing', 'VBG'), (',', ','), ('he', 'PRP'), ('led', 'VBD'), ('him', 'PRP'), ('out', 'RP'), ('into', 'IN'), ('the', 'DT'), ('sealed', 'VBN'), Tree('NP', [('garden', 'NN')]), (',', ','), ('talked', 'VBD'), ('about', 'IN'), Tree('NP', [('swordsmanship', 'NN')]), (',', ','), ('used', 'VBD'), Tree('NP', [('twigs', 'NNS')]), ('and', 'CC'), ('a', 'DT'), Tree('NP', [('sabre', 'NN')]), ('for', 'IN'), Tree('NP', [('illustration', 'NN')]), (',', ','), ('and—', 'JJ'), ('”', 'NNP'), ('Ivan', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Scar', 'NNP'), ('sprang', 'VBD'), ('up', 'RP'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('“', 'NN')]), ('You', 'PRP'), ('lunatic', 'JJ'), (',', ','), ('”', 'EX'), ('he', 'PRP'), ('yelled', 'VBD'), (';', ':'), ('“', 'NNP'), ('you', 'PRP'), ('’', 'VBP'), ('ll', 'JJ'), ('go', 'VBP'), ('to', 'TO'), ('my', 'PRP$'), Tree('NP', [('master', 'NN')]), ('now', 'RB'), (',', ','), ('if', 'IN'), ('I', 'PRP'), ('take', 'VBP'), ('you', 'PRP'), ('by—', 'VBP'), ('”', 'JJ'), ('“', 'NNP'), ('Why', 'WRB'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ('going', 'VBG'), ('there', 'RB'), (',', ','), ('”', 'NNP'), ('said', 'VBD'), ('Brown', 'NNP'), ('heavily', 'RB'), (';', ':'), ('“', 'CC'), ('I', 'PRP'), ('must', 'MD'), ('ask', 'VB'), ('him', 'PRP'), ('to', 'TO'), ('confess', 'VB'), (',', ','), ('and', 'CC'), ('all', 'DT'), Tree('NP', [('that.', 'NN')]), ('”', 'NNP'), ('Driving', 'NNP'), ('the', 'DT'), ('unhappy', 'JJ'), ('Brown', 'NNP'), ('before', 'IN'), ('them', 'PRP'), ('like', 'IN'), ('a', 'DT'), Tree('NP', [('hostage', 'NN')]), ('or', 'CC'), Tree('NP', [('sacrifice', 'NN')]), (',', ','), ('they', 'PRP'), ('rushed', 'VBD'), ('together', 'RB'), ('into', 'IN'), ('the', 'DT'), Tree('NP', [('sudden', 'JJ'), ('stillness', 'NN')]), ('of', 'IN'), ('Valentin', 'NNP'), ('’', 'NNP'), Tree('NP', [('s', 'NN'), ('study', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('NP', [('great', 'JJ'), ('detective', 'JJ'), ('sat', 'NN')]), ('at', 'IN'), ('his', 'PRP$'), Tree('NP', [('desk', 'NN')]), ('apparently', 'RB'), ('too', 'RB'), ('occupied', 'JJ'), ('to', 'TO'), ('hear', 'VB'), ('their', 'PRP$'), Tree('NP', [('turbulent', 'JJ'), ('entrance', 'NN')]), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('paused', 'VBD'), ('a', 'DT'), Tree('NP', [('moment', 'NN')]), (',', ','), ('and', 'CC'), ('then', 'RB'), Tree('NP', [('something', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('look', 'NN')]), ('of', 'IN'), ('that', 'DT'), ('upright', 'JJ'), ('and', 'CC'), ('elegant', 'JJ'), ('back', 'RB'), ('made', 'VBD'), ('the', 'DT'), Tree('NP', [('doctor', 'NN')]), ('run', 'VB'), ('forward', 'RB'), ('suddenly', 'RB'), ('.', '.')]),
#  Tree('S', [('A', 'DT'), Tree('NP', [('touch', 'NN')]), ('and', 'CC'), ('a', 'DT'), Tree('NP', [('glance', 'NN')]), ('showed', 'VBD'), ('him', 'PRP'), ('that', 'IN'), ('there', 'EX'), ('was', 'VBD'), ('a', 'DT'), Tree('NP', [('small', 'JJ'), ('box', 'NN')]), ('of', 'IN'), Tree('NP', [('pills', 'NNS')]), ('at', 'IN'), ('Valentin', 'NNP'), ('’', 'NNP'), Tree('NP', [('s', 'NN'), ('elbow', 'NN')]), (',', ','), ('and', 'CC'), ('that', 'IN'), ('Valentin', 'NNP'), ('was', 'VBD'), ('dead', 'JJ'), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('chair', 'NN')]), (';', ':'), ('and', 'CC'), ('on', 'IN'), ('the', 'DT'), Tree('NP', [('blind', 'JJ'), ('face', 'NN')]), ('of', 'IN'), ('the', 'DT'), Tree('NP', [('suicide', 'NN')]), ('was', 'VBD'), ('more', 'JJR'), ('than', 'IN'), ('the', 'DT'), Tree('NP', [('pride', 'NN')]), ('of', 'IN'), ('Cato', 'NNP')])]

# %%
def NP_chunked(sentences):
  nps = []
  chunked_NP = nltk.RegexpParser(grammar)
  for sent in sentences:
    tree = chunked_NP.parse(sent)
    for subtree in tree.subtrees():
      if subtree.label() == 'NP':
        t = subtree
        t = ' '.join(word for word, tag in t.leaves())
        nps.append(t)
  return nps

# %%
print("The extracted noun phrases are")
text = chunked_text(docs)
text_noun_phrases = NP_chunked(text)

print(text_noun_phrases)
# Out:
# The extracted noun phrases are
# ['dinner', 'guests', 'confidential servant', 'old man', 'scar', 'face', 'moustaches', 'table', 'entrance hall—a hall hung', 'weapons', 's house', 'peculiar', 'master', 'old house', 'high walls', 'tall poplars', 'oddity—and', 'police', 'architecture', 'ultimate exit', 'front door', 'armoury', 'garden', 'many exits', 'house', 'garden', 'exit', 'garden', 'world', 'tall', 'unscalable wall', 'special spikes', 'top', 'bad garden', 'man', 'criminals', 'guests', 'host', 'ten minutes', 'truth', 'last arrangements', 'executions', 'such ugly things', 'duties', 'precision', 'Ruthless', 'pursuit', 'criminals', 'punishment', 'methods', 'great influence', 'mitigation', 'sentences', 'purification', 'prisons', 'great humanitarian French freethinkers', 'only thing', 'justice', 'black clothes', 'red rosette—an', 'elegant figure', 'dark beard', 'grey', 'house', 'study', 'grounds', 'garden door', 'box', 'official place', 'few seconds', 'open door', 'garden', 'sharp moon', 'rags', 'tatters', 'storm', 'such scientific natures', 'such scientific natures', 'psychic prevision', 'tremendous problem', 'lives', 'such occult mood', 'guests', 'glance', 'drawing-room', 'principal guest', 'rate', 'other pillars', 'little party', 'choleric old man', 'russet face', 'apple', 'blue ribbon', 'slim', 'threadlike', 'silver hair', 'face', 'daughter', 'pale', 'girl', 'elfish face', 'copper-coloured hair', 'daughters', 'opulent', 'typical French scientist', 'glasses', 'pointed brown beard', 'forehead', 'parallel wrinkles', 'penalty', 'superciliousness', 'eyebrows', 'interest', 'these—a', 'tall man', 'hearty acknowledgment', 'respects', 'host', 'swaggering figure', 'officer', 'famous regiment', 'victorious failures', 'successful suicides', 'air', 'melancholy', 'birth', 'Irish gentleman', 'boyhood', 'country', 'crash', 'debts', 'complete freedom', 'British etiquette', 'uniform', 'sabre', 'spurs', 'family', 'bent stiffly', 'old causes', 'such people', 'host', 'one', 'eyes', 'guest', 'evening', 'special reasons', 'man', 'world-wide fame', 'friendship', 'great detective tours', 'triumphs', 'multi-millionaire', 'colossal', 'endowments', 'small religions', 'much easy sport', 'solemnity', 'English papers', 'Nobody', 'atheist', 'Christian Scientist', 'money', 'intellectual vessel', 'untried vessel', 'hobbies', 'hobby', '“ progressive ”', 'day', 'anything', 'progressive. ”', 'progressive', 'grave injustice', 'solid appearance', 'room', 'dinner bell', 'great quality', 'presence', 'absence', 'huge fellow', 'complete evening', 'much relief', 'watch-chain', 'ring', 'hair', 'German ’ s', 'face', 'dark tuft', 'lip', 'infantile visage', 'effect theatrical', 'salon', 'stare', 'lateness', 'domestic problem', 'speed', 'dining-room', 'arm', 'point', 'arm', 'adventurer', 'father', 'restless', 'rude', 'dinner', 'cigars', 'doctor', 'priest', 'exile', 'foreign uniform—all', 'ladies', 'smoke', 'conservatory', 'diplomatist', 'sixty', 'thought', 'scamp', 'coffee', 'hoary Yankee', 'religions', 'none', 'time', '“ progressive ” logomachy', 'crisis', 'tedium', 'drawing-room', 'way', 'long passages', 'minutes', 'till', 'didactic voice', 'doctor', 'dull voice', 'priest', 'general laughter', 'curse', 'science', 'religion. ”', 'instant', 'salon door', 'thing—he', 'drawing-room', 'dining-room', 'passage', 'notion', 'daughter', 'Irish-Algerian n ’ er-do-well', 'something', 'mad', 'mind', 'back', 'house', 's study', 'daughter', 'scornful face', 'second enigma', 'sort', 'senile', 'passionate suspicion', 'way', 'dark', 'parts', 'mansion', 'servants', '’ entrance', 'garden', 'moon', 'scimitar', 'storm-wrack', 'argent light', 'corners', 'garden', 'tall figure', 'blue', 'lawn', 'study door', 'glint', 'moonlit silver', 'facings', 'French windows', 'house', 'indescribable temper', 'blue-and-silver garden', 'scene', 'theatre', 'tyrannic tenderness', 'worldly authority', 'war', 'length', 'grace', 'father', 'moonlight', 'magic', 'garden', 'troubadours', 'fairyland', 'such amorous imbecilities', 'speech', 'enemy', 'tr ...
